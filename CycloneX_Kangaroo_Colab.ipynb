# %% [markdown]
# # 🦘 CycloneX — Kangaroo Solver (Google Colab Edition v2.0)
#
# Solver de alta performance para o **Puzzle #140** com **Warp Batch Inversion (Afim Puro)** e **Foco Probabilístico Mid-Range (30%-70%)**.
#
# ## ⚡ Como Rodar no Google Colab (2 passos rápidos):
# 1. No menu superior em **Ambiente de Execução** (Runtime):
#    - Clique em **Alterar tipo de ambiente de execução**.
#    - Escolha **GPU (T4)** e salve.
# 2. Execute a **Célula de Código** abaixo (botão Play ou `Ctrl + Enter`).
#
# > 💾 **Resultado Garantido:** Se a chave privada for encontrada, ela é salva automaticamente no arquivo `/content/FOUND_KEY.txt`!

# %%
# 🚀 Execução do CycloneX Engine no Google Colab
# !git clone https://github.com/ggsofthouse/cycloneX.git /content/cycloneX && python /content/cycloneX/run_kaggle.py
