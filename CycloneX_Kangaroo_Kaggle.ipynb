# %% [markdown]
# # 🦘 CycloneX — Kangaroo Solver (Kaggle Edition v2.0)
#
# Solver de alta performance com **Coordenadas Jacobianas Mistas (0 Inversões Modulares no Loop)** e **Distribuição Ótima de Teske** para o **Puzzle #140**.
#
# ## ⚡ Como Rodar no Kaggle (2 passos rápidos):
# 1. No painel à direita em **Notebook options**:
#    - **Accelerator:** Mude para `GPU T4 x2` (ou `GPU P100`).
#    - **Internet:** Mude para `On`.
# 2. Execute a **Célula de Código** abaixo (botão Play ou `Shift + Enter`).
#
# > 💾 **Resultado Garantido:** Se a chave privada for encontrada, ela é salva automaticamente no arquivo persistente `/kaggle/working/FOUND_KEY.txt` para você baixar!

# %%
# 🚀 Execução do CycloneX Engine v2.0 nas GPUs do Kaggle
# !git clone https://github.com/ggsofthouse/cycloneX.git /kaggle/working/cycloneX && python /kaggle/working/cycloneX/run_kaggle.py

# %% [markdown]
# ---
# ### 📁 Onde a chave é salva se for encontrada?
# A chave privada HEX é gravada instantaneamente em `/kaggle/working/FOUND_KEY.txt` e exibida no painel de saída.
# Para baixar o arquivo no Kaggle:
# 1. No painel lateral direito, clique na aba **Output**.
# 2. Clique com o botão direito em `FOUND_KEY.txt` $\rightarrow$ **Download**.
